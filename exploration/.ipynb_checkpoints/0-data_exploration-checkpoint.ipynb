# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import re
import os
from matplotlib.ticker import MaxNLocator
import matplotlib.pyplot as plt
from requests import get
from bs4 import BeautifulSoup
from pandas.util import hash_pandas_object
from tqdm import tqdm

# %%
data = pd.read_csv('../data/en.openfoodfacts.org.products.csv', sep = '\t')
# Out:
# /home/yann/anaconda3/envs/ada/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (0,24,25,26,28,44,49) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head(10)
# Out:
#                    code                                                url  \
# 0         0000000000017  http://world-en.openfoodfacts.org/product/0000...
# 1         0000000000031  http://world-en.openfoodfacts.org/product/0000...
# 2         0000000000100  http://world-en.openfoodfacts.org/product/0000...
# 3  00000000001111111111  http://world-en.openfoodfacts.org/product/0000...
# 4         0000000000123  http://world-en.openfoodfacts.org/product/0000...
# 5         0000000000178  http://world-en.openfoodfacts.org/product/0000...
# 6         0000000000208  http://world-en.openfoodfacts.org/product/0000...
# 7         0000000000284  http://world-en.openfoodfacts.org/product/0000...
# 8         0000000000291  http://world-en.openfoodfacts.org/product/0000...
# 9         0000000000949  http://world-en.openfoodfacts.org/product/0000...
#
#                       creator   created_t      created_datetime  \
# 0                     kiliweb  1529059080  2018-06-15T10:38:00Z
# 1                    isagoofy  1539464774  2018-10-13T21:06:14Z
# 2                       del51  1444572561  2015-10-11T14:09:21Z
# 3  openfoodfacts-contributors  1560020173  2019-06-08T18:56:13Z
# 4                     kiliweb  1535737982  2018-08-31T17:53:02Z
# 5                     kiliweb  1542456332  2018-11-17T12:05:32Z
# 6                     kiliweb  1544207680  2018-12-07T18:34:40Z
# 7                     kiliweb  1547120245  2019-01-10T11:37:25Z
# 8                     kiliweb  1534239669  2018-08-14T09:41:09Z
# 9                     kiliweb  1523440813  2018-04-11T10:00:13Z
#
#    last_modified_t last_modified_datetime                  product_name  \
# 0       1561463718   2019-06-25T11:55:18Z              Vitória crackers
# 1       1539464817   2018-10-13T21:06:57Z                         Cacao
# 2       1444659212   2015-10-12T14:13:32Z   moutarde au moût de raisin
# 3       1560020173   2019-06-08T18:56:13Z                       Sfiudwx
# 4       1535737986   2018-08-31T17:53:06Z         Sauce Sweety chili 0%
# 5       1542456333   2018-11-17T12:05:33Z                     Mini coco
# 6       1544207683   2018-12-07T18:34:43Z         Pistou d'ail des ours
# 7       1563551052   2019-07-19T15:44:12Z                     Pain maïs
# 8       1534239732   2018-08-14T09:42:12Z                     Mendiants
# 9       1565268412   2019-08-08T12:46:52Z     Salade de carottes râpées
#
#   generic_name quantity  ... carbon-footprint-from-meat-or-fish_100g  \
# 0          NaN      NaN  ...                                     NaN
# 1          NaN    130 g  ...                                     NaN
# 2          NaN     100g  ...                                     NaN
# 3          NaN    dgesc  ...                                     NaN
# 4          NaN      NaN  ...                                     NaN
# 5          NaN      NaN  ...                                     NaN
# 6          NaN      NaN  ...                                     NaN
# 7          NaN      NaN  ...                                     NaN
# 8          NaN      NaN  ...                                     NaN
# 9          NaN      NaN  ...                                     NaN
#
#   nutrition-score-fr_100g nutrition-score-uk_100g glycemic-index_100g  \
# 0                     NaN                     NaN                 NaN
# 1                     NaN                     NaN                 NaN
# 2                    18.0                    18.0                 NaN
# 3                     NaN                     NaN                 NaN
# 4                     NaN                     NaN                 NaN
# 5                     NaN                     NaN                 NaN
# 6                     NaN                     NaN                 NaN
# 7                     NaN                     NaN                 NaN
# 8                     NaN                     NaN                 NaN
# 9                     1.0                     1.0                 NaN
#
#   water-hardness_100g choline_100g phylloquinone_100g beta-glucan_100g  \
# 0                 NaN          NaN                NaN              NaN
# 1                 NaN          NaN                NaN              NaN
# 2                 NaN          NaN                NaN              NaN
# 3                 NaN          NaN                NaN              NaN
# 4                 NaN          NaN                NaN              NaN
# 5                 NaN          NaN                NaN              NaN
# 6                 NaN          NaN                NaN              NaN
# 7                 NaN          NaN                NaN              NaN
# 8                 NaN          NaN                NaN              NaN
# 9                 NaN          NaN                NaN              NaN
#
#   inositol_100g carnitine_100g
# 0           NaN            NaN
# 1           NaN            NaN
# 2           NaN            NaN
# 3           NaN            NaN
# 4           NaN            NaN
# 5           NaN            NaN
# 6           NaN            NaN
# 7           NaN            NaN
# 8           NaN            NaN
# 9           NaN            NaN
#
# [10 rows x 175 columns]

# %%
# - fields that end with _t are dates in the UNIX timestamp format (number of seconds since Jan 1st 1970)
data_unixdate = data[data.columns[[x.endswith('_t') for x in data.columns]]]
# - fields that end with _datetime are dates in the iso8601 format: yyyy-mm-ddThh:mn:ssZ
data_dateiso8601 = data[data.columns[[x.endswith('_datetime') for x in data.columns]]]
# - fields that end with _tags are comma separated list of tags (e.g. categories_tags is the set of normalized tags computer from the categories field)
data_categorytags= data[data.columns[[x.endswith('_tags') for x in data.columns]]]
# - fields that end with _100g correspond to the amount of a nutriment (in g, or kJ for energy) for 100 g or 100 ml of product
data_100gnutri= data[data.columns[[x.endswith('_100g') for x in data.columns]]]
#- fields that end with _serving correspond to the amount of a nutriment (in g, or kJ for energy) for 1 serving of the product
data_servnutri= data[data.columns[[x.endswith('_serving') for x in data.columns]]]

# %% [markdown]
# ## Missing Values

# %%
#Creation of Missing Percentage DataFrame 
missing_percentages = pd.DataFrame({'field' : data.columns.values, 'Nb NA': data.columns.values, '% NA': data.columns.values}) 
missing_percentages = missing_percentages.set_index(['field'])
for col in data.columns:
    miss = (data[col].size-data[col].count())
    tot = data[col].size
    percentage = round((100*(data[col].size-data[col].count())/data[col].size))
    print("The field --%(col)s-- contained %(miss)d missing entries : %(miss)d/%(tot)d = %(percentage)d percentages of missing entries"\
          % {'col': str(col), 'miss': miss, 'tot': tot, 'percentage': percentage})
    missing_percentages.loc[col, "Nb NA"] = miss
    missing_percentages.loc[col, "% NA"] = percentage
    
missing_percentages.head(50)
# Out:
# The field --code-- contained 0 missing entries : 0/1034826 = 0 percentages of missing entries
# The field --url-- contained 0 missing entries : 0/1034826 = 0 percentages of missing entries
# The field --creator-- contained 4 missing entries : 4/1034826 = 0 percentages of missing entries
# The field --created_t-- contained 0 missing entries : 0/1034826 = 0 percentages of missing entries
# The field --created_datetime-- contained 1 missing entries : 1/1034826 = 0 percentages of missing entries
# The field --last_modified_t-- contained 0 missing entries : 0/1034826 = 0 percentages of missing entries
# The field --last_modified_datetime-- contained 0 missing entries : 0/1034826 = 0 percentages of missing entries
# The field --product_name-- contained 51496 missing entries : 51496/1034826 = 5 percentages of missing entries
# The field --generic_name-- contained 942230 missing entries : 942230/1034826 = 91 percentages of missing entries
# The field --quantity-- contained 712645 missing entries : 712645/1034826 = 69 percentages of missing entries
# The field --packaging-- contained 849377 missing entries : 849377/1034826 = 82 percentages of missing entries
# The field --packaging_tags-- contained 849384 missing entries : 849384/1034826 = 82 percentages of missing entries
# The field --brands-- contained 430890 missing entries : 430890/1034826 = 42 percentages of missing entries
# The field --brands_tags-- contained 430941 missing entries : 430941/1034826 = 42 percentages of missing entries
# The field --categories-- contained 653317 missing entries : 653317/1034826 = 63 percentages of missing entries
# The field --categories_tags-- contained 653321 missing entries : 653321/1034826 = 63 percentages of missing entries
# The field --categories_en-- contained 653321 missing entries : 653321/1034826 = 63 percentages of missing entries
# The field --origins-- contained 980112 missing entries : 980112/1034826 = 95 percentages of missing entries
# The field --origins_tags-- contained 980212 missing entries : 980212/1034826 = 95 percentages of missing entries
# The field --manufacturing_places-- contained 948474 missing entries : 948474/1034826 = 92 percentages of missing entries
# The field --manufacturing_places_tags-- contained 948509 missing entries : 948509/1034826 = 92 percentages of missing entries
# The field --labels-- contained 831736 missing entries : 831736/1034826 = 80 percentages of missing entries
# The field --labels_tags-- contained 831712 missing entries : 831712/1034826 = 80 percentages of missing entries
# The field --labels_en-- contained 831712 missing entries : 831712/1034826 = 80 percentages of missing entries
# The field --emb_codes-- contained 968692 missing entries : 968692/1034826 = 94 percentages of missing entries
# The field --emb_codes_tags-- contained 968721 missing entries : 968721/1034826 = 94 percentages of missing entries
# The field --first_packaging_code_geo-- contained 992456 missing entries : 992456/1034826 = 96 percentages of missing entries
# The field --cities-- contained 1034826 missing entries : 1034826/1034826 = 100 percentages of missing entries
# The field --cities_tags-- contained 989358 missing entries : 989358/1034826 = 96 percentages of missing entries
# The field --purchase_places-- contained 911339 missing entries : 911339/1034826 = 88 percentages of missing entries
# The field --stores-- contained 853750 missing entries : 853750/1034826 = 83 percentages of missing entries
# The field --countries-- contained 1782 missing entries : 1782/1034826 = 0 percentages of missing entries
# The field --countries_tags-- contained 1783 missing entries : 1783/1034826 = 0 percentages of missing entries
# The field --countries_en-- contained 1783 missing entries : 1783/1034826 = 0 percentages of missing entries
# The field --ingredients_text-- contained 585444 missing entries : 585444/1034826 = 57 percentages of missing entries
# The field --allergens-- contained 951288 missing entries : 951288/1034826 = 92 percentages of missing entries
# The field --allergens_en-- contained 1034826 missing entries : 1034826/1034826 = 100 percentages of missing entries
# The field --traces-- contained 970947 missing entries : 970947/1034826 = 94 percentages of missing entries
# The field --traces_tags-- contained 952595 missing entries : 952595/1034826 = 92 percentages of missing entries
# The field --traces_en-- contained 952595 missing entries : 952595/1034826 = 92 percentages of missing entries
# The field --serving_size-- contained 755570 missing entries : 755570/1034826 = 73 percentages of missing entries
# The field --serving_quantity-- contained 755446 missing entries : 755446/1034826 = 73 percentages of missing entries
# The field --no_nutriments-- contained 1034826 missing entries : 1034826/1034826 = 100 percentages of missing entries
# The field --additives_n-- contained 585564 missing entries : 585564/1034826 = 57 percentages of missing entries
# The field --additives-- contained 1034789 missing entries : 1034789/1034826 = 100 percentages of missing entries
# The field --additives_tags-- contained 790309 missing entries : 790309/1034826 = 76 percentages of missing entries
# The field --additives_en-- contained 790309 missing entries : 790309/1034826 = 76 percentages of missing entries
# The field --ingredients_from_palm_oil_n-- contained 585564 missing entries : 585564/1034826 = 57 percentages of missing entries
# The field --ingredients_from_palm_oil-- contained 1034826 missing entries : 1034826/1034826 = 100 percentages of missing entries
# The field --ingredients_from_palm_oil_tags-- contained 1022731 missing entries : 1022731/1034826 = 99 percentages of missing entries
# The field --ingredients_that_may_be_from_palm_oil_n-- contained 585564 missing entries : 585564/1034826 = 57 percentages of missing entries
# The field --ingredients_that_may_be_from_palm_oil-- contained 1034826 missing entries : 1034826/1034826 = 100 percentages of missing entries
# The field --ingredients_that_may_be_from_palm_oil_tags-- contained 1008485 missing entries : 1008485/1034826 = 97 percentages of missing entries
# The field --nutrition_grade_fr-- contained 741529 missing entries : 741529/1034826 = 72 percentages of missing entries
# The field --nova_group-- contained 711625 missing entries : 711625/1034826 = 69 percentages of missing entries
# The field --pnns_groups_1-- contained 10719 missing entries : 10719/1034826 = 1 percentages of missing entries
# The field --pnns_groups_2-- contained 395 missing entries : 395/1034826 = 0 percentages of missing entries
# The field --states-- contained 0 missing entries : 0/1034826 = 0 percentages of missing entries
# The field --states_tags-- contained 0 missing entries : 0/1034826 = 0 percentages of missing entries
# The field --states_en-- contained 0 missing entries : 0/1034826 = 0 percentages of missing entries
# The field --main_category-- contained 653387 missing entries : 653387/1034826 = 63 percentages of missing entries
# The field --main_category_en-- contained 653387 missing entries : 653387/1034826 = 63 percentages of missing entries
# The field --image_url-- contained 266551 missing entries : 266551/1034826 = 26 percentages of missing entries
# The field --image_small_url-- contained 266551 missing entries : 266551/1034826 = 26 percentages of missing entries
# The field --image_ingredients_url-- contained 450410 missing entries : 450410/1034826 = 44 percentages of missing entries
# The field --image_ingredients_small_url-- contained 450410 missing entries : 450410/1034826 = 44 percentages of missing entries
# The field --image_nutrition_url-- contained 680942 missing entries : 680942/1034826 = 66 percentages of missing entries
# The field --image_nutrition_small_url-- contained 680942 missing entries : 680942/1034826 = 66 percentages of missing entries
# The field --energy_100g-- contained 207548 missing entries : 207548/1034826 = 20 percentages of missing entries
# The field --energy-from-fat_100g-- contained 1033874 missing entries : 1033874/1034826 = 100 percentages of missing entries
# The field --fat_100g-- contained 212289 missing entries : 212289/1034826 = 21 percentages of missing entries
# The field --saturated-fat_100g-- contained 241977 missing entries : 241977/1034826 = 23 percentages of missing entries
# The field ---butyric-acid_100g-- contained 1034825 missing entries : 1034825/1034826 = 100 percentages of missing entries
# The field ---caproic-acid_100g-- contained 1034826 missing entries : 1034826/1034826 = 100 percentages of missing entries
# The field ---caprylic-acid_100g-- contained 1034825 missing entries : 1034825/1034826 = 100 percentages of missing entries
# The field ---capric-acid_100g-- contained 1034822 missing entries : 1034822/1034826 = 100 percentages of missing entries
# The field ---lauric-acid_100g-- contained 1034819 missing entries : 1034819/1034826 = 100 percentages of missing entries
# The field ---myristic-acid_100g-- contained 1034825 missing entries : 1034825/1034826 = 100 percentages of missing entries
# The field ---palmitic-acid_100g-- contained 1034823 missing entries : 1034823/1034826 = 100 percentages of missing entries
# The field ---stearic-acid_100g-- contained 1034825 missing entries : 1034825/1034826 = 100 percentages of missing entries
# The field ---arachidic-acid_100g-- contained 1034824 missing entries : 1034824/1034826 = 100 percentages of missing entries
# The field ---behenic-acid_100g-- contained 1034825 missing entries : 1034825/1034826 = 100 percentages of missing entries
# The field ---lignoceric-acid_100g-- contained 1034826 missing entries : 1034826/1034826 = 100 percentages of missing entries
# The field ---cerotic-acid_100g-- contained 1034823 missing entries : 1034823/1034826 = 100 percentages of missing entries
# The field ---montanic-acid_100g-- contained 1034825 missing entries : 1034825/1034826 = 100 percentages of missing entries
# The field ---melissic-acid_100g-- contained 1034826 missing entries : 1034826/1034826 = 100 percentages of missing entries
# The field --monounsaturated-fat_100g-- contained 1010452 missing entries : 1010452/1034826 = 98 percentages of missing entries
# The field --polyunsaturated-fat_100g-- contained 1010399 missing entries : 1010399/1034826 = 98 percentages of missing entries
# The field --omega-3-fat_100g-- contained 1033272 missing entries : 1033272/1034826 = 100 percentages of missing entries
# The field ---alpha-linolenic-acid_100g-- contained 1034530 missing entries : 1034530/1034826 = 100 percentages of missing entries
# The field ---eicosapentaenoic-acid_100g-- contained 1034727 missing entries : 1034727/1034826 = 100 percentages of missing entries
# The field ---docosahexaenoic-acid_100g-- contained 1034693 missing entries : 1034693/1034826 = 100 percentages of missing entries
# The field --omega-6-fat_100g-- contained 1034452 missing entries : 1034452/1034826 = 100 percentages of missing entries
# The field ---linoleic-acid_100g-- contained 1034627 missing entries : 1034627/1034826 = 100 percentages of missing entries
# The field ---arachidonic-acid_100g-- contained 1034811 missing entries : 1034811/1034826 = 100 percentages of missing entries
# The field ---gamma-linolenic-acid_100g-- contained 1034822 missing entries : 1034822/1034826 = 100 percentages of missing entries
# The field ---dihomo-gamma-linolenic-acid_100g-- contained 1034825 missing entries : 1034825/1034826 = 100 percentages of missing entries
# The field --omega-9-fat_100g-- contained 1034787 missing entries : 1034787/1034826 = 100 percentages of missing entries
# The field ---oleic-acid_100g-- contained 1034805 missing entries : 1034805/1034826 = 100 percentages of missing entries
# The field ---elaidic-acid_100g-- contained 1034826 missing entries : 1034826/1034826 = 100 percentages of missing entries
# The field ---gondoic-acid_100g-- contained 1034826 missing entries : 1034826/1034826 = 100 percentages of missing entries
# The field ---mead-acid_100g-- contained 1034826 missing entries : 1034826/1034826 = 100 percentages of missing entries
# The field ---erucic-acid_100g-- contained 1034826 missing entries : 1034826/1034826 = 100 percentages of missing entries
# The field ---nervonic-acid_100g-- contained 1034826 missing entries : 1034826/1034826 = 100 percentages of missing entries
# The field --trans-fat_100g-- contained 890481 missing entries : 890481/1034826 = 86 percentages of missing entries
# The field --cholesterol_100g-- contained 889690 missing entries : 889690/1034826 = 86 percentages of missing entries
# The field --carbohydrates_100g-- contained 212330 missing entries : 212330/1034826 = 21 percentages of missing entries
# The field --sugars_100g-- contained 226411 missing entries : 226411/1034826 = 22 percentages of missing entries
# The field ---sucrose_100g-- contained 1034708 missing entries : 1034708/1034826 = 100 percentages of missing entries
# The field ---glucose_100g-- contained 1034777 missing entries : 1034777/1034826 = 100 percentages of missing entries
# The field ---fructose_100g-- contained 1034758 missing entries : 1034758/1034826 = 100 percentages of missing entries
# The field ---lactose_100g-- contained 1034403 missing entries : 1034403/1034826 = 100 percentages of missing entries
# The field ---maltose_100g-- contained 1034817 missing entries : 1034817/1034826 = 100 percentages of missing entries
# The field ---maltodextrins_100g-- contained 1034812 missing entries : 1034812/1034826 = 100 percentages of missing entries
# The field --starch_100g-- contained 1034443 missing entries : 1034443/1034826 = 100 percentages of missing entries
# The field --polyols_100g-- contained 1034038 missing entries : 1034038/1034826 = 100 percentages of missing entries
# The field --fiber_100g-- contained 732120 missing entries : 732120/1034826 = 71 percentages of missing entries
# The field --proteins_100g-- contained 210425 missing entries : 210425/1034826 = 20 percentages of missing entries
# The field --casein_100g-- contained 1034788 missing entries : 1034788/1034826 = 100 percentages of missing entries
# The field --serum-proteins_100g-- contained 1034792 missing entries : 1034792/1034826 = 100 percentages of missing entries
# The field --nucleotides_100g-- contained 1034814 missing entries : 1034814/1034826 = 100 percentages of missing entries
# The field --salt_100g-- contained 230191 missing entries : 230191/1034826 = 22 percentages of missing entries
# The field --sodium_100g-- contained 230239 missing entries : 230239/1034826 = 22 percentages of missing entries
# The field --alcohol_100g-- contained 1022068 missing entries : 1022068/1034826 = 99 percentages of missing entries
# The field --vitamin-a_100g-- contained 895747 missing entries : 895747/1034826 = 87 percentages of missing entries
# The field --beta-carotene_100g-- contained 1034757 missing entries : 1034757/1034826 = 100 percentages of missing entries
# The field --vitamin-d_100g-- contained 1026404 missing entries : 1026404/1034826 = 99 percentages of missing entries
# The field --vitamin-e_100g-- contained 1032338 missing entries : 1032338/1034826 = 100 percentages of missing entries
# The field --vitamin-k_100g-- contained 1033801 missing entries : 1033801/1034826 = 100 percentages of missing entries
# The field --vitamin-c_100g-- contained 892181 missing entries : 892181/1034826 = 86 percentages of missing entries
# The field --vitamin-b1_100g-- contained 1022452 missing entries : 1022452/1034826 = 99 percentages of missing entries
# The field --vitamin-b2_100g-- contained 1022969 missing entries : 1022969/1034826 = 99 percentages of missing entries
# The field --vitamin-pp_100g-- contained 1022167 missing entries : 1022167/1034826 = 99 percentages of missing entries
# The field --vitamin-b6_100g-- contained 1026927 missing entries : 1026927/1034826 = 99 percentages of missing entries
# The field --vitamin-b9_100g-- contained 1028781 missing entries : 1028781/1034826 = 99 percentages of missing entries
# The field --folates_100g-- contained 1031744 missing entries : 1031744/1034826 = 100 percentages of missing entries
# The field --vitamin-b12_100g-- contained 1028491 missing entries : 1028491/1034826 = 99 percentages of missing entries
# The field --biotin_100g-- contained 1034262 missing entries : 1034262/1034826 = 100 percentages of missing entries
# The field --pantothenic-acid_100g-- contained 1031803 missing entries : 1031803/1034826 = 100 percentages of missing entries
# The field --silica_100g-- contained 1034726 missing entries : 1034726/1034826 = 100 percentages of missing entries
# The field --bicarbonate_100g-- contained 1034562 missing entries : 1034562/1034826 = 100 percentages of missing entries
# The field --potassium_100g-- contained 1008633 missing entries : 1008633/1034826 = 97 percentages of missing entries
# The field --chloride_100g-- contained 1034317 missing entries : 1034317/1034826 = 100 percentages of missing entries
# The field --calcium_100g-- contained 888692 missing entries : 888692/1034826 = 86 percentages of missing entries
# The field --phosphorus_100g-- contained 1028080 missing entries : 1028080/1034826 = 99 percentages of missing entries
# The field --iron_100g-- contained 892065 missing entries : 892065/1034826 = 86 percentages of missing entries
# The field --magnesium_100g-- contained 1027028 missing entries : 1027028/1034826 = 99 percentages of missing entries
# The field --zinc_100g-- contained 1030252 missing entries : 1030252/1034826 = 100 percentages of missing entries
# The field --copper_100g-- contained 1032530 missing entries : 1032530/1034826 = 100 percentages of missing entries
# The field --manganese_100g-- contained 1032961 missing entries : 1032961/1034826 = 100 percentages of missing entries
# The field --fluoride_100g-- contained 1034597 missing entries : 1034597/1034826 = 100 percentages of missing entries
# The field --selenium_100g-- contained 1033498 missing entries : 1033498/1034826 = 100 percentages of missing entries
# The field --chromium_100g-- contained 1034768 missing entries : 1034768/1034826 = 100 percentages of missing entries
# The field --molybdenum_100g-- contained 1034766 missing entries : 1034766/1034826 = 100 percentages of missing entries
# The field --iodine_100g-- contained 1034233 missing entries : 1034233/1034826 = 100 percentages of missing entries
# The field --caffeine_100g-- contained 1034573 missing entries : 1034573/1034826 = 100 percentages of missing entries
# The field --taurine_100g-- contained 1034729 missing entries : 1034729/1034826 = 100 percentages of missing entries
# The field --ph_100g-- contained 1034684 missing entries : 1034684/1034826 = 100 percentages of missing entries
# The field --fruits-vegetables-nuts_100g-- contained 1029070 missing entries : 1029070/1034826 = 99 percentages of missing entries
# The field --fruits-vegetables-nuts-dried_100g-- contained 1034543 missing entries : 1034543/1034826 = 100 percentages of missing entries
# The field --fruits-vegetables-nuts-estimate_100g-- contained 1024746 missing entries : 1024746/1034826 = 99 percentages of missing entries
# The field --collagen-meat-protein-ratio_100g-- contained 1034539 missing entries : 1034539/1034826 = 100 percentages of missing entries
# The field --cocoa_100g-- contained 1030315 missing entries : 1030315/1034826 = 100 percentages of missing entries
# The field --chlorophyl_100g-- contained 1034824 missing entries : 1034824/1034826 = 100 percentages of missing entries
# The field --carbon-footprint_100g-- contained 1034420 missing entries : 1034420/1034826 = 100 percentages of missing entries
# The field --carbon-footprint-from-meat-or-fish_100g-- contained 1025509 missing entries : 1025509/1034826 = 99 percentages of missing entries
# The field --nutrition-score-fr_100g-- contained 741530 missing entries : 741530/1034826 = 72 percentages of missing entries
# The field --nutrition-score-uk_100g-- contained 741530 missing entries : 741530/1034826 = 72 percentages of missing entries
# The field --glycemic-index_100g-- contained 1034823 missing entries : 1034823/1034826 = 100 percentages of missing entries
# The field --water-hardness_100g-- contained 1034826 missing entries : 1034826/1034826 = 100 percentages of missing entries
# The field --choline_100g-- contained 1034792 missing entries : 1034792/1034826 = 100 percentages of missing entries
# The field --phylloquinone_100g-- contained 1034822 missing entries : 1034822/1034826 = 100 percentages of missing entries
# The field --beta-glucan_100g-- contained 1034806 missing entries : 1034806/1034826 = 100 percentages of missing entries
# The field --inositol_100g-- contained 1034789 missing entries : 1034789/1034826 = 100 percentages of missing entries
# The field --carnitine_100g-- contained 1034811 missing entries : 1034811/1034826 = 100 percentages of missing entries
#                                   Nb NA % NA
# field
# code                                  0    0
# url                                   0    0
# creator                               4    0
# created_t                             0    0
# created_datetime                      1    0
# last_modified_t                       0    0
# last_modified_datetime                0    0
# product_name                      51496    5
# generic_name                     942230   91
# quantity                         712645   69
# packaging                        849377   82
# packaging_tags                   849384   82
# brands                           430890   42
# brands_tags                      430941   42
# categories                       653317   63
# categories_tags                  653321   63
# categories_en                    653321   63
# origins                          980112   95
# origins_tags                     980212   95
# manufacturing_places             948474   92
# manufacturing_places_tags        948509   92
# labels                           831736   80
# labels_tags                      831712   80
# labels_en                        831712   80
# emb_codes                        968692   94
# emb_codes_tags                   968721   94
# first_packaging_code_geo         992456   96
# cities                          1034826  100
# cities_tags                      989358   96
# purchase_places                  911339   88
# stores                           853750   83
# countries                          1782    0
# countries_tags                     1783    0
# countries_en                       1783    0
# ingredients_text                 585444   57
# allergens                        951288   92
# allergens_en                    1034826  100
# traces                           970947   94
# traces_tags                      952595   92
# traces_en                        952595   92
# serving_size                     755570   73
# serving_quantity                 755446   73
# no_nutriments                   1034826  100
# additives_n                      585564   57
# additives                       1034789  100
# additives_tags                   790309   76
# additives_en                     790309   76
# ingredients_from_palm_oil_n      585564   57
# ingredients_from_palm_oil       1034826  100
# ingredients_from_palm_oil_tags  1022731   99

# %% [markdown]
# ## Investigating new categories for diet type

# %% [markdown]
# First, we look at fields that can be used in order to create new diet type categorie

# %%
#categories field
print("The categories field contained %d not nan unique entries\n" % data[data.categories.notnull()].categories.unique().shape)
data[data["categories"].notnull()]["categories"].unique()
for categorie in data[data["categories"].notnull()]["categories"].unique()[:15]:
    print(categorie)
# Out:
# The categories field contained 79016 not nan unique entries
#
# Epicerie,Condiments,Sauces,Moutardes
# fr:Xsf
# Plats préparés, Légumes préparés, Carottes râpées, Carottes râpées assaisonnées
# Tartes, Tartes sucrées, Tartes à la noix de coco
# Aliments et boissons à base de végétaux, Aliments d'origine végétale, Aliments à base de fruits et de légumes, Desserts, Fruits et produits dérivés, Compotes, Compotes de poire
# Viandes, Volailles, Poulets, Aiguillettes de poulet
# Plats préparés, Légumes préparés, Entrées, Entrées froides, Macédoines de légumes préparées
# Produits laitiers, Produits fermentés, Produits laitiers fermentés, Fromages, Fromages de France, Abondance
# Viandes, Volailles, Poulets, Cuisses de poulet
# Aliments et boissons à base de végétaux, Aliments d'origine végétale, Céréales et pommes de terre, Pains, Pains spéciaux, Pains Bagel
# Aliments et boissons à base de végétaux, Aliments d'origine végétale, Céréales et pommes de terre, Pains, Baguettes
# Produits de la mer, Poissons, Saumons, Poissons fumés, Saumons fumés, Pavés de saumon, Pavés de saumon fumé
# Conserves, Viandes en conserve, Corned beef
# Produits de la mer, Poissons, Saumons, Pavés de saumon
# Plats préparés, Salades, Salades composées

# %%
#pnns_groups_1 field
print("The pnns_groups_1 field contained %d not nan unique entries" % data[data.pnns_groups_1.notnull()].pnns_groups_1.unique().shape)
for pnns in data[data["pnns_groups_1"].notnull()]["pnns_groups_1"].unique():
    print(pnns)
# Out:
# The pnns_groups_1 field contained 14 not nan unique entries
# unknown
# Fat and sauces
# Composite foods
# Sugary snacks
# Fruits and vegetables
# Fish Meat Eggs
# Milk and dairy products
# Cereals and potatoes
# sugary-snacks
# Beverages
# Salty snacks
# fruits-and-vegetables
# cereals-and-potatoes
# salty-snacks

# %%
#pnns_groups_2 field
print("The pnns_groups_2 field contained %d not nan unique entries" % data[data.pnns_groups_2.notnull()].pnns_groups_2.unique().shape)
for pnns in data[data["pnns_groups_2"].notnull()]["pnns_groups_2"].unique():
    print(pnns)
# Out:
# The pnns_groups_2 field contained 46 not nan unique entries
# unknown
# Dressings and sauces
# One-dish meals
# Biscuits and cakes
# Fruits
# Meat
# Cheese
# Bread
# Fish and seafood
# Dried fruits
# Legumes
# Vegetables
# Dairy desserts
# pastries
# Fruit juices
# Sweetened beverages
# Unsweetened beverages
# Pizza pies and quiche
# Sweets
# Alcoholic beverages
# Salty and fatty products
# Cereals
# Appetizers
# Fats
# Processed meat
# Nuts
# Chocolate products
# Milk and yogurt
# Ice cream
# Breakfast cereals
# vegetables
# Teas and herbal teas and coffees
# Sandwiches
# Soups
# Potatoes
# Artificially sweetened beverages
# Plant-based milk substitutes
# Offals
# fruits
# Eggs
# Waters and flavored waters
# Fruit nectars
# cereals
# Pizza pies and quiches
# legumes
# nuts

# %%
#labels_en
print("The labels_en field contained %d not nan unique entries" % data[data.labels_en.notnull()].labels_en.unique().shape)
for label in data[data["labels_en"].notnull()]['labels_en'].unique()[:50]:
    print(label)
    
#Output comment
# - labels_en --> Organic, Vegetarian, Vegan, Lactose-free, Gluten-Free
# Out:
# The labels_en field contained 35106 not nan unique entries
# fr:delois-france
# Organic
# Organic,EU Organic,FR-BIO-01
# Organic,EU Organic,EU/non-EU Agriculture,FR-BIO-15
# Organic,EU Organic,fr:ab-agriculture-biologique
# Made in France
# Low or no fat,Low fat,Organic,High fibres
# fr:viande-francaise,Made in France
# Green Dot
# Contains GMOs
# Nutriscore,Nutriscore Grade A
# Made in Spain
# Organic,EU Organic,FR-BIO-10,fr:ab-agriculture-biologique
# Kosher,Contains GMOs
# No artificial flavors,Contains GMOs
# Gluten-free
# Incorrect data on label
# Not advised for specific people,PDO,Made in France,With sulfites,fr:Déconseillé aux femmes enceintes,fr:Origine France,fr:Triman
# Sustainable farming,UTZ Certified,UTZ Certified Cacao
# Do not freeze again
# Low or no sugar,Contains a source of phenylalanine,Excessive consumption can have laxative effects,Green Dot,No sugar,With sweeteners
# Vegetarian,No artificial colors,No flavors,No preservatives
# Organic,EU Organic,NL-BIO-01
# de:0000080176800
# Vegetarian,Vegan
# No preservatives,No thickening agent
# Gluten-free,Palm oil free
# Organic,EU Organic,FR-BIO-10
# No colorings
# Made in France,No preservatives
# Gluten-free,No lactose
# No colorings,No preservatives
# Organic,EU Organic,FR-BIO-01,fr:ab-agriculture-biologique
# No preservatives
# Green Dot,Made in France
# Vegetarian,Gluten-free,No GMOs,High proteins,Superior quality,fr:Triman
# Vegetarian,Gluten-free,No GMOs,High proteins
# PGI
# Organic,EU Organic,IT-BIO-009
# Organic,EU Organic,Gluten-free,FR-BIO-01,No added sugar,No lactose,Palm oil free
# Gluten-free,No preservatives
# Vegetarian,Gluten-free,Vegan,No lactose
# Vegetarian,Vegan,No added sugar,No lactose
# Vegetarian,Gluten-free,Vegan,No added sugar,No lactose
# Organic,EU Organic,FR-BIO-01,Made in France
# No additives,No colorings
# French meat,fr:Viande Bovine Française
# No artificial flavors,Green Dot,No artificial colors
# Pure butter
# Vegetarian,Green Dot,Pure butter

# %%
#ingredients_text
print("The ingredients_text field contained %d not nan unique entries \n" % data[data.ingredients_text.notnull()].ingredients_text.unique().shape)
for label in data[data["ingredients_text"].notnull()]['ingredients_text'].unique()[:50]:
    print(label + '\n')

#Output comment
# - ingredients_text --> Organic
# Out:
# The ingredients_text field contained 393971 not nan unique entries
#
# eau graines de téguments de moutarde vinaigre de vin rouge sel vin rouge sucre   moût de raisin (6.2%) oignons colorants extraits de carotte et extrait de paprika huile de tournesol son de moutarde sel (cette _moutarde_ uniquement disponible chez courte paille)
#
# antioxydant : érythorbate de sodium, colorant : caramel - origine UE), tomate 33,3%, MAYONNAISE 11,1% (huile de colza 78,9%, eau, jaunes d'OEUF 6%, vinaigre, MOUTARDE [eau, graines de MOUTARDE, sel, vinaigre, curcuma], sel, dextrose, stabilisateur : gomme de cellulose, conservateur : sorbate de potassium, colorant : ?-carotène, arôme)
#
# Lait entier, sucre, amidon de maïs, cacao, Agar agar.
#
# baguette Poite vin Pain baguette 50,6%: farine de BLÉ, eau, sel, levure, GLUTEN, farine de BLE maité, levure désactivée, acide ascorbique, Garniture FROMAGE mi-chèvre 46% (LAIT pasteurisé [95 0% LAIT de vache, 5 0% LAIT de chèvre], sel, FERMENTS LACTIQUES et daffinage, coagulant), tomate saladg 20,4%, huile d'olive I basilic 1%
#
# Paln suédois 42,6%: farine de BLÉ, eau, farine de SEIGLE, sucre, huile de colza non hydrogénée, sirop de sucre, gluten de BLÉ, sel, levure, levain en poudre (SEIGLE), poudre à lever: E503, fructose, agent de traitement de la farine: E300, enzymes. Garniture 57,4%: SAUMON Atlantique, sel origine Frane6,-Fdorvège, ÉëòS%EChlli), salade 29,6%, FROMAGE BLANO.Z,8% MG 14,8%, c)b'oulette
#
# Taboulé 76,2%, légumes 12%, huile de colza, sel , menthe, jus de citron, sucre, conservateur : E202, arôme
#
# Bananas, vegetable oil (coconut oil, corn oil and/or palm oil) sugar, natural banana flavor.
#
# Peanuts, wheat flour, sugar, rice flour, tapioca starch, salt, leavening (ammonium bicarbonate, baking soda), soy sauce (water, soybeans, wheat, salt), potato starch.
#
# FROMAGE BLANC 7.896 MG 73,304, crème de marron vanillée 26,71 % (sucre. pur60 do châtaignes 38%, naturel do vanil!o).
#
# pain aux 6 céréqles 61,7 % farine (farine de BLÉ, GLUTEN de BLE), eu, mélange 6 céréales-3 graines 17,6% (farine de BLE complet, crème d'ORGE, farine d'AVOlNE, farine de maïs, semoule de BLÉ dur, graines cie millet, graines de lin, graines de SÉSAME, farine de SEIGLE), sel, levure, garniture 38,3% , coppa 30,2% (échine de porc, sel, dextrose de maïs, fenouil, arome naturel, sucre, conservateur: nitrate de potassium et nitrite de sodium -origine UE), salade 30,2%, tomate 30,2%, basilic 5%, huile d'olive.
#
# Bâguette Bressan Pain baguette 46,2%,' farine de BLÉ, eau, sel, levure, GLUTEN, farine de BLE malté, levure désactivée, acide ascorbique, Garniture 53,8%: filet de poulet braisé 34,3% (filet de poulet 82%, eau, acidifiant : lactate de potassium et acétate de sodium, amidon modifié de manioc, sel, dextrose glucose, arômes, gélifiants E407ayaM$xydant : érythèfbate de sodium, colorant : grafnel • origine UE), tomateN25x8%, OEUF dur 22,70/ , 'salade 17,20/ O
#
# Organic hazelnuts, organic cashews, organic walnuts almonds, organic sunflower oil, sea salt.
#
# Organic polenta
#
# Rolled oats, grape concentrate, expeller pressed canola oil, sunflower seeds, almonds, walnuts oat bran, sesame seeds, cashews, natural vitamin e.
#
# Organic long grain white rice
#
# Org oats, org hemp granola (org oats, evaporated cane juice, org expeller-pressed canola oil, crispy rice [org brown rice flour, org evaporated cane juice, org molasses, sea salt], org flax seeds, org oat solids, hemp seeds), org raisins, org dates, org almonds, org hazelnuts, org coconut, org sunflower seeds, org pumpkin seeds, org flax seeds, org corn flakes (org corn meal, org grape and/or pear juice concentrate, sea salt), org quinoa amaranth flakes (org corn meal, org yellow corn flour, org evaporated cane juice, org flax, org buckwheat flour, org quinoa, org amaranth, sea salt, tocopherols [natural vitamin e]).
#
# Organic chocolate liquor, organic raw cane sugar, organic cocoa butter, organic unrefined whole cane sugar, organic ground vanilla beans.
#
# Organic expeller pressed, refined high oleic sunflower oil
#
# Organic adzuki beans
#
# Organic refined durum semolina wheat flour
#
# Roasted peanuts (peanuts, peanut or canola oil, salt), sesame sticks (unbleached wheat flour, sesame seeds, sunflower oil, sa;t, beet powder, turmeric), chili crackers (rice, corn starch, soy sauce[water, soybeans, wheat, salt], brown rice syrup, paprika, onion powder, garlic powder), tamari roasted almonds (almonds, tamari shoyu [water, wheat, soybeans, salt]), salt
#
# Organic golden flax seeds
#
# Organic dry roasted pumpkin seeds, tamari (soybeans, water and salt), garlic and cayenne.
#
# Organic rolled oats, honey, raisins, almonds, sunflower seeds, walnuts, wheat germ, unrefined expeller-pressed safflower oil, molasses, cinnamon
#
# Organic raw hazelnuts.
#
# Organic bananas, organic coconut oil, organic sugar
#
# Organic brown jasmine rice
#
# Organic oat groats
#
# Yogurt raisins, tamari roasted almonds, organic tamari roasted soy nuts, dark chocolate stars, cranberries, dark chocolate chips, peanut butter chips, milk chocolate raisins, pineapple, papaya, peanut butter peanuts & raisins, roasted peanuts.
#
# Chocolate stars (dehydrated cane juice, sweetened chocolate, cocoa butter, soy lecithin [an emulsifier], natural vanilla), roasted peanuts (peanuts, safflower, peanut, and/or canola oil, salt), dry roasted almonds (almonds, sea salt), dry roasted cashews (cashews, sea salt), dried cranberries (cranberries, evaporated cane juice, sunflower oil), dried cherries, walnuts, dried blueberries (blueberries, evaporated cane juice, sunflower oil).
#
# Organic rolled oats, organic evaporated cane juice, organic quinoa flakes, organic raisins, organic expeller pressed canola oil, organic mango, organic oat bran, organic coconut.
#
# Dry roasted almonds, hatch green chile seasoning (organic cheddar cheese powder [organic cheddar cheese {cultured pasteurized milk, salt, enzymes}, organic nonfat milk,organic whey, salt, sodium phosphate], salt, hatch green chile pepper, evaporated cane juice, onion, parsely, natural flavors,garlic, maltodextrin, spices, spices extractives, citric acid), expeller pressed canola oil.
#
# Peanut butter (dry roasted peanuts, palm oil, salt), honey, crispy brown rice (brown rice flour [rice flour, rice bran], honey, calcium carbonate), barley malt, soy lecithin (an emulsifier), sea salt, locust bean gum, carrageenan gum.
#
# Ancient sea salt with natural trace minerals
#
# Organic whole rolled oats, organic expeller pressed canola oil, organic raisins, organic coconut, organic corn meal, organic flax seed, organic freeze dried raspberries, organic freeze dried blueberries, organic vanilla, salt.
#
# Whole cashews, sunflower oil, salt, black pepper
#
# Cashews, curry seasoning (salt, maltodextrin, spices, torula yeast, onion, garlic, turmeric, extractives of spice and natural flavor), canola oil.
#
# Almonds, wasabi spice (salt, rice flour, evaporated cane juice, onion powder, spice extracts, horseradish powder, yeast extract, dried parsley, spice, garlic powder, citric acid), tamari shoyu sauce (water, soybeans, salt, wheat)
#
# Organic coconut
#
# Organic red quinoa
#
# Coconut bar (coconut, brown rice syrup), dark chocolate coating (unsweetened chocolate, dehydrated cane juice, cocoa butter, soy lecithin [as an emulsifier], natural vanilla).
#
# Organic semi-sweet chocolate chips (organic sugar, organic chocolate liquor, organic cocoa butter, soy lecithin, organic vanilla), organic pumpkin seeds, organic almonds, organic cranberries (sweetened with organic cane juice), organic raisins, organic coconut, organic sunflower seeds.
#
# Organic whole rolled oates, organic raisins, organic expeller pressed canola oil, organic flax seed, organic corn meal, organic almonds, organic coconut, organic cinnamon, salt.
#
# Organic rolled oats, organic evaporated cane juice, organic expeller pressed canola oil, organic raisins, organic apples, organic almonds, organic oat bran, organic blueberries, organic sunflower seeds.
#
# Raw cane demerara sugar.
#
# Organic rolled oats, flame raisins, organic coconut chips, organic maple syrup, sunflower oil, walnuts, roasted diced almonds, wheat germ, honey, crunchy almond butter (dry roasted almonds), hazelnuts, almonds, organic ground cinnamon, organic vanilla extract.
#
# Organic coconut.
#
# Organic black beans
#
# Bluebird grain organic grain emmer farro
#
# Organic hard red wheat berries.

# %% [markdown]
# ## Type of diet to create new diet category

# %% [markdown]
# Information taken from https://larecolteenvrac.com/articles/les-differents-regimes-alimentaires
#
# 8 different types of diet:
# * Vegetarianism
# * Pesco-vegetarianism
#      - Pas sur de le garder celui ci il sert à R
# * Flexitarism
#     - Idem cas tous les aliments sont flexitarism, par d'interet de le mettre partout
# * Veganism
# * Gluten-free
# * Lactose-free
# * Ketogenic
# * Organic

# %%
diet_data = pd.DataFrame({'Diet':['Vegetarianism',\
                                  'Pesco-vegetarianism',\
                                  'Flexitarism',\
                                  'Veganism',\
                                  'Gluten-free',\
                                  'Lactose-free',\
                                  'Ketogenic'],\
                        'Eat': [['fruit', 'vegetable', 'grain', 'egg', 'dairy'],
                                ['fish', 'seafood', 'egg', 'dairy'],
                                ['less meat'],
                                ['fruit', 'vegetable', 'grain', 'nut', 'vegetable milk', 'vegan cheese', 'meet imitation'],
                                ['meat', 'fish', 'dairy', 'fruit', 'vegetable', 'nut', 'gluten-free bread', 'gluten-free pasta'],
                                ['meat', 'fish', 'fruit', 'vegetable', 'grain'],
                                ['fat meat', 'fat fish', 'dairy', 'less fruit', 'less vegetable', 'food high in saturated fat']],
                        'Avoid':[['meat', 'fish', 'seafood'],
                                ['meat'],
                                [None],
                                ['meat', 'fish', 'seafood'],
                                ['wheat', 'barley', 'rye', 'breadcrumbs', 'beer', 'soya'],
                                ['dairy'],
                                ['candy', 'pasta', 'rice', 'potato', 'bread', 'cereal']]}).set_index('Diet')
diet_data.loc['Organic'] = ['organic food', 'non-organic food']
diet_data
# Out:
#                                                                    Eat  \
# Diet
# Vegetarianism                    [fruit, vegetable, grain, egg, dairy]
# Pesco-vegetarianism                        [fish, seafood, egg, dairy]
# Flexitarism                                                [less meat]
# Veganism             [fruit, vegetable, grain, nut, vegetable milk,...
# Gluten-free          [meat, fish, dairy, fruit, vegetable, nut, glu...
# Lactose-free                     [meat, fish, fruit, vegetable, grain]
# Ketogenic            [fat meat, fat fish, dairy, less fruit, less v...
# Organic                                                   organic food
#
#                                                              Avoid
# Diet
# Vegetarianism                                [meat, fish, seafood]
# Pesco-vegetarianism                                         [meat]
# Flexitarism                                                 [None]
# Veganism                                     [meat, fish, seafood]
# Gluten-free          [wheat, barley, rye, breadcrumbs, beer, soya]
# Lactose-free                                               [dairy]
# Ketogenic              [candy, pasta, rice, potato, bread, cereal]
# Organic                                           non-organic food

# %%
data['diet'] = np.empty((len(data),0)).tolist()
data.head()
# Out:
#                    code                                                url  \
# 0         0000000000017  http://world-en.openfoodfacts.org/product/0000...
# 1         0000000000031  http://world-en.openfoodfacts.org/product/0000...
# 2         0000000000100  http://world-en.openfoodfacts.org/product/0000...
# 3  00000000001111111111  http://world-en.openfoodfacts.org/product/0000...
# 4         0000000000123  http://world-en.openfoodfacts.org/product/0000...
#
#                       creator   created_t      created_datetime  \
# 0                     kiliweb  1529059080  2018-06-15T10:38:00Z
# 1                    isagoofy  1539464774  2018-10-13T21:06:14Z
# 2                       del51  1444572561  2015-10-11T14:09:21Z
# 3  openfoodfacts-contributors  1560020173  2019-06-08T18:56:13Z
# 4                     kiliweb  1535737982  2018-08-31T17:53:02Z
#
#    last_modified_t last_modified_datetime                  product_name  \
# 0       1561463718   2019-06-25T11:55:18Z              Vitória crackers
# 1       1539464817   2018-10-13T21:06:57Z                         Cacao
# 2       1444659212   2015-10-12T14:13:32Z   moutarde au moût de raisin
# 3       1560020173   2019-06-08T18:56:13Z                       Sfiudwx
# 4       1535737986   2018-08-31T17:53:06Z         Sauce Sweety chili 0%
#
#   generic_name quantity  ... nutrition-score-fr_100g nutrition-score-uk_100g  \
# 0          NaN      NaN  ...                     NaN                     NaN
# 1          NaN    130 g  ...                     NaN                     NaN
# 2          NaN     100g  ...                    18.0                    18.0
# 3          NaN    dgesc  ...                     NaN                     NaN
# 4          NaN      NaN  ...                     NaN                     NaN
#
#   glycemic-index_100g water-hardness_100g choline_100g phylloquinone_100g  \
# 0                 NaN                 NaN          NaN                NaN
# 1                 NaN                 NaN          NaN                NaN
# 2                 NaN                 NaN          NaN                NaN
# 3                 NaN                 NaN          NaN                NaN
# 4                 NaN                 NaN          NaN                NaN
#
#   beta-glucan_100g inositol_100g carnitine_100g diet
# 0              NaN           NaN            NaN   []
# 1              NaN           NaN            NaN   []
# 2              NaN           NaN            NaN   []
# 3              NaN           NaN            NaN   []
# 4              NaN           NaN            NaN   []
#
# [5 rows x 176 columns]

# %% [markdown]
# ## Creation of the new diet field

# %%
def create_diet(data, field):
    """Create new diet categories by looking at the infos given in the corresponding field 
        Diet field must be previously created in data (nan values)"""
    
    if field == 'labels_en': 
        
        for ind, label in enumerate(tqdm(data[field])):
            
            if ('Organic' in str(label)) & ('Organic' not in str(data.loc[ind, 'diet'])):
                data.loc[ind, 'diet'].append('Organic')   
            if ('Vegetarian' in str(label)) & ('Vegetarian' not in str(data.loc[ind, 'diet'])):
                data.loc[ind, 'diet'].append('Vegetarian')     
            if ('Vegan' in str(label)) & ('Vegan' not in str(data.loc[ind, 'diet'])):
                data.loc[ind, 'diet'].append('Vegan')           
            if ('Gluten-free' in str(label)) & ('Gluten-free' not in str(data.loc[ind, 'diet'])):
                data.loc[ind, 'diet'].append('Gluten-free') 
            if ('No lactose' in str(label)) & ('Lactose-free' not in str(data.loc[ind, 'diet'])):
                data.loc[ind, 'diet'].append('Lactose-free') 
    
    if field = ''

# %%
str(data_test.loc[40, 'diet'])
# Out:
# "['Organic']"

# %%
data_test = data.copy()
create_diet(data_test, 'labels_en')
# Out:
# 100%|██████████| 1034826/1034826 [01:04<00:00, 15940.52it/s]

# %%
data_test[data_test['labels_en']=='Vegetarian,Gluten-free,Vegan,No lactose']['diet'].iloc[1]
# Out:
# ['Vegetarian', 'Vegan', 'Gluten-free', 'Lactose-free']

# %%
print("%d%% of diet entries have been created" % (len(data_test[data_test['diet'].str.len() >0])/len(data_test)*100))
# Out:
# 9% of diet entries have been created
