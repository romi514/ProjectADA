# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import re
import os
from matplotlib.ticker import MaxNLocator
import matplotlib.pyplot as plt
from requests import get
from bs4 import BeautifulSoup
from pandas.util import hash_pandas_object

# %%
data = pd.read_csv('../data/en.openfoodfacts.org.products.csv', sep = '\t')
# Out:
# /home/yann/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (0,24,25,26,28,44,49) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# - fields that end with _t are dates in the UNIX timestamp format (number of seconds since Jan 1st 1970)
data_unixdate = data[data.columns[[x.endswith('_t') for x in data.columns]]]

# - fields that end with _datetime are dates in the iso8601 format: yyyy-mm-ddThh:mn:ssZ
data_dateiso8601 = data[data.columns[[x.endswith('_datetime') for x in data.columns]]]

# - fields that end with _tags are comma separated list of tags (e.g. categories_tags is the set of normalized tags computer from the categories field)
data_categorytags= data[data.columns[[x.endswith('_tags') for x in data.columns]]]

# - fields that end with _100g correspond to the amount of a nutriment (in g, or kJ for energy) for 100 g or 100 ml of product
data_100gnutri= data[data.columns[[x.endswith('_100g') for x in data.columns]]]

#- fields that end with _serving correspond to the amount of a nutriment (in g, or kJ for energy) for 1 serving of the product
data_servnutri= data[data.columns[[x.endswith('_serving') for x in data.columns]]]

# %% [markdown]
# ## Missing Values

# %%
#Creation of Missing Percentage DataFrame 
missing_percentages = pd.DataFrame({'field' : data.columns.values, 'Nb NA': data.columns.values, '% NA': data.columns.values}) 
missing_percentages = missing_percentages.set_index(['field'])
for col in data.columns:
    miss = (data[col].size-data[col].count())
    tot = data[col].size
    percentage = round((100*(data[col].size-data[col].count())/data[col].size))
    print("The field --%(col)s-- contained %(miss)d missing entries : %(miss)d/%(tot)d = %(percentage)d percentages of missing entries"\
          % {'col': str(col), 'miss': miss, 'tot': tot, 'percentage': percentage})
    missing_percentages.loc[col, "Nb NA"] = miss
    missing_percentages.loc[col, "% NA"] = percentage
    
missing_percentages.head(50)
# Out:
# The field --code-- contained 0 missing entries : 0/1017858 = 0 percentages of missing entries
# The field --url-- contained 0 missing entries : 0/1017858 = 0 percentages of missing entries
# The field --creator-- contained 3 missing entries : 3/1017858 = 0 percentages of missing entries
# The field --created_t-- contained 0 missing entries : 0/1017858 = 0 percentages of missing entries
# The field --created_datetime-- contained 1 missing entries : 1/1017858 = 0 percentages of missing entries
# The field --last_modified_t-- contained 0 missing entries : 0/1017858 = 0 percentages of missing entries
# The field --last_modified_datetime-- contained 0 missing entries : 0/1017858 = 0 percentages of missing entries
# The field --product_name-- contained 49872 missing entries : 49872/1017858 = 5 percentages of missing entries
# The field --generic_name-- contained 925571 missing entries : 925571/1017858 = 91 percentages of missing entries
# The field --quantity-- contained 699415 missing entries : 699415/1017858 = 69 percentages of missing entries
# The field --packaging-- contained 830876 missing entries : 830876/1017858 = 82 percentages of missing entries
# The field --packaging_tags-- contained 830883 missing entries : 830883/1017858 = 82 percentages of missing entries
# The field --brands-- contained 420303 missing entries : 420303/1017858 = 41 percentages of missing entries
# The field --brands_tags-- contained 420353 missing entries : 420353/1017858 = 41 percentages of missing entries
# The field --categories-- contained 642555 missing entries : 642555/1017858 = 63 percentages of missing entries
# The field --categories_tags-- contained 642559 missing entries : 642559/1017858 = 63 percentages of missing entries
# The field --categories_en-- contained 642559 missing entries : 642559/1017858 = 63 percentages of missing entries
# The field --origins-- contained 963001 missing entries : 963001/1017858 = 95 percentages of missing entries
# The field --origins_tags-- contained 963100 missing entries : 963100/1017858 = 95 percentages of missing entries
# The field --manufacturing_places-- contained 931980 missing entries : 931980/1017858 = 92 percentages of missing entries
# The field --manufacturing_places_tags-- contained 932015 missing entries : 932015/1017858 = 92 percentages of missing entries
# The field --labels-- contained 818467 missing entries : 818467/1017858 = 80 percentages of missing entries
# The field --labels_tags-- contained 818444 missing entries : 818444/1017858 = 80 percentages of missing entries
# The field --labels_en-- contained 818444 missing entries : 818444/1017858 = 80 percentages of missing entries
# The field --emb_codes-- contained 951918 missing entries : 951918/1017858 = 94 percentages of missing entries
# The field --emb_codes_tags-- contained 951947 missing entries : 951947/1017858 = 94 percentages of missing entries
# The field --first_packaging_code_geo-- contained 975797 missing entries : 975797/1017858 = 96 percentages of missing entries
# The field --cities-- contained 1017858 missing entries : 1017858/1017858 = 100 percentages of missing entries
# The field --cities_tags-- contained 972715 missing entries : 972715/1017858 = 96 percentages of missing entries
# The field --purchase_places-- contained 895031 missing entries : 895031/1017858 = 88 percentages of missing entries
# The field --stores-- contained 837691 missing entries : 837691/1017858 = 82 percentages of missing entries
# The field --countries-- contained 1742 missing entries : 1742/1017858 = 0 percentages of missing entries
# The field --countries_tags-- contained 1743 missing entries : 1743/1017858 = 0 percentages of missing entries
# The field --countries_en-- contained 1743 missing entries : 1743/1017858 = 0 percentages of missing entries
# The field --ingredients_text-- contained 569761 missing entries : 569761/1017858 = 56 percentages of missing entries
# The field --allergens-- contained 934726 missing entries : 934726/1017858 = 92 percentages of missing entries
# The field --allergens_en-- contained 1017858 missing entries : 1017858/1017858 = 100 percentages of missing entries
# The field --traces-- contained 954395 missing entries : 954395/1017858 = 94 percentages of missing entries
# The field --traces_tags-- contained 936084 missing entries : 936084/1017858 = 92 percentages of missing entries
# The field --traces_en-- contained 936084 missing entries : 936084/1017858 = 92 percentages of missing entries
# The field --serving_size-- contained 739636 missing entries : 739636/1017858 = 73 percentages of missing entries
# The field --serving_quantity-- contained 739520 missing entries : 739520/1017858 = 73 percentages of missing entries
# The field --no_nutriments-- contained 1017858 missing entries : 1017858/1017858 = 100 percentages of missing entries
# The field --additives_n-- contained 569883 missing entries : 569883/1017858 = 56 percentages of missing entries
# The field --additives-- contained 1017828 missing entries : 1017828/1017858 = 100 percentages of missing entries
# The field --additives_tags-- contained 774039 missing entries : 774039/1017858 = 76 percentages of missing entries
# The field --additives_en-- contained 774039 missing entries : 774039/1017858 = 76 percentages of missing entries
# The field --ingredients_from_palm_oil_n-- contained 569883 missing entries : 569883/1017858 = 56 percentages of missing entries
# The field --ingredients_from_palm_oil-- contained 1017858 missing entries : 1017858/1017858 = 100 percentages of missing entries
# The field --ingredients_from_palm_oil_tags-- contained 1005782 missing entries : 1005782/1017858 = 99 percentages of missing entries
# The field --ingredients_that_may_be_from_palm_oil_n-- contained 569883 missing entries : 569883/1017858 = 56 percentages of missing entries
# The field --ingredients_that_may_be_from_palm_oil-- contained 1017858 missing entries : 1017858/1017858 = 100 percentages of missing entries
# The field --ingredients_that_may_be_from_palm_oil_tags-- contained 991583 missing entries : 991583/1017858 = 97 percentages of missing entries
# The field --nutrition_grade_fr-- contained 729484 missing entries : 729484/1017858 = 72 percentages of missing entries
# The field --nova_group-- contained 695829 missing entries : 695829/1017858 = 68 percentages of missing entries
# The field --pnns_groups_1-- contained 10794 missing entries : 10794/1017858 = 1 percentages of missing entries
# The field --pnns_groups_2-- contained 544 missing entries : 544/1017858 = 0 percentages of missing entries
# The field --states-- contained 0 missing entries : 0/1017858 = 0 percentages of missing entries
# The field --states_tags-- contained 0 missing entries : 0/1017858 = 0 percentages of missing entries
# The field --states_en-- contained 0 missing entries : 0/1017858 = 0 percentages of missing entries
# The field --main_category-- contained 642627 missing entries : 642627/1017858 = 63 percentages of missing entries
# The field --main_category_en-- contained 642627 missing entries : 642627/1017858 = 63 percentages of missing entries
# The field --image_url-- contained 266042 missing entries : 266042/1017858 = 26 percentages of missing entries
# The field --image_small_url-- contained 266042 missing entries : 266042/1017858 = 26 percentages of missing entries
# The field --image_ingredients_url-- contained 434883 missing entries : 434883/1017858 = 43 percentages of missing entries
# The field --image_ingredients_small_url-- contained 434883 missing entries : 434883/1017858 = 43 percentages of missing entries
# The field --image_nutrition_url-- contained 678329 missing entries : 678329/1017858 = 67 percentages of missing entries
# The field --image_nutrition_small_url-- contained 678329 missing entries : 678329/1017858 = 67 percentages of missing entries
# The field --energy_100g-- contained 202403 missing entries : 202403/1017858 = 20 percentages of missing entries
# The field --energy-from-fat_100g-- contained 1016907 missing entries : 1016907/1017858 = 100 percentages of missing entries
# The field --fat_100g-- contained 207144 missing entries : 207144/1017858 = 20 percentages of missing entries
# The field --saturated-fat_100g-- contained 236794 missing entries : 236794/1017858 = 23 percentages of missing entries
# The field ---butyric-acid_100g-- contained 1017857 missing entries : 1017857/1017858 = 100 percentages of missing entries
# The field ---caproic-acid_100g-- contained 1017858 missing entries : 1017858/1017858 = 100 percentages of missing entries
# The field ---caprylic-acid_100g-- contained 1017857 missing entries : 1017857/1017858 = 100 percentages of missing entries
# The field ---capric-acid_100g-- contained 1017854 missing entries : 1017854/1017858 = 100 percentages of missing entries
# The field ---lauric-acid_100g-- contained 1017851 missing entries : 1017851/1017858 = 100 percentages of missing entries
# The field ---myristic-acid_100g-- contained 1017857 missing entries : 1017857/1017858 = 100 percentages of missing entries
# The field ---palmitic-acid_100g-- contained 1017855 missing entries : 1017855/1017858 = 100 percentages of missing entries
# The field ---stearic-acid_100g-- contained 1017857 missing entries : 1017857/1017858 = 100 percentages of missing entries
# The field ---arachidic-acid_100g-- contained 1017856 missing entries : 1017856/1017858 = 100 percentages of missing entries
# The field ---behenic-acid_100g-- contained 1017857 missing entries : 1017857/1017858 = 100 percentages of missing entries
# The field ---lignoceric-acid_100g-- contained 1017858 missing entries : 1017858/1017858 = 100 percentages of missing entries
# The field ---cerotic-acid_100g-- contained 1017855 missing entries : 1017855/1017858 = 100 percentages of missing entries
# The field ---montanic-acid_100g-- contained 1017857 missing entries : 1017857/1017858 = 100 percentages of missing entries
# The field ---melissic-acid_100g-- contained 1017858 missing entries : 1017858/1017858 = 100 percentages of missing entries
# The field --monounsaturated-fat_100g-- contained 993495 missing entries : 993495/1017858 = 98 percentages of missing entries
# The field --polyunsaturated-fat_100g-- contained 993444 missing entries : 993444/1017858 = 98 percentages of missing entries
# The field --omega-3-fat_100g-- contained 1016312 missing entries : 1016312/1017858 = 100 percentages of missing entries
# The field ---alpha-linolenic-acid_100g-- contained 1017562 missing entries : 1017562/1017858 = 100 percentages of missing entries
# The field ---eicosapentaenoic-acid_100g-- contained 1017760 missing entries : 1017760/1017858 = 100 percentages of missing entries
# The field ---docosahexaenoic-acid_100g-- contained 1017726 missing entries : 1017726/1017858 = 100 percentages of missing entries
# The field --omega-6-fat_100g-- contained 1017486 missing entries : 1017486/1017858 = 100 percentages of missing entries
# The field ---linoleic-acid_100g-- contained 1017659 missing entries : 1017659/1017858 = 100 percentages of missing entries
# The field ---arachidonic-acid_100g-- contained 1017843 missing entries : 1017843/1017858 = 100 percentages of missing entries
# The field ---gamma-linolenic-acid_100g-- contained 1017854 missing entries : 1017854/1017858 = 100 percentages of missing entries
# The field ---dihomo-gamma-linolenic-acid_100g-- contained 1017857 missing entries : 1017857/1017858 = 100 percentages of missing entries
# The field --omega-9-fat_100g-- contained 1017819 missing entries : 1017819/1017858 = 100 percentages of missing entries
# The field ---oleic-acid_100g-- contained 1017837 missing entries : 1017837/1017858 = 100 percentages of missing entries
# The field ---elaidic-acid_100g-- contained 1017858 missing entries : 1017858/1017858 = 100 percentages of missing entries
# The field ---gondoic-acid_100g-- contained 1017858 missing entries : 1017858/1017858 = 100 percentages of missing entries
# The field ---mead-acid_100g-- contained 1017858 missing entries : 1017858/1017858 = 100 percentages of missing entries
# The field ---erucic-acid_100g-- contained 1017858 missing entries : 1017858/1017858 = 100 percentages of missing entries
# The field ---nervonic-acid_100g-- contained 1017858 missing entries : 1017858/1017858 = 100 percentages of missing entries
# The field --trans-fat_100g-- contained 873517 missing entries : 873517/1017858 = 86 percentages of missing entries
# The field --cholesterol_100g-- contained 872728 missing entries : 872728/1017858 = 86 percentages of missing entries
# The field --carbohydrates_100g-- contained 207190 missing entries : 207190/1017858 = 20 percentages of missing entries
# The field --sugars_100g-- contained 221243 missing entries : 221243/1017858 = 22 percentages of missing entries
# The field ---sucrose_100g-- contained 1017740 missing entries : 1017740/1017858 = 100 percentages of missing entries
# The field ---glucose_100g-- contained 1017810 missing entries : 1017810/1017858 = 100 percentages of missing entries
# The field ---fructose_100g-- contained 1017790 missing entries : 1017790/1017858 = 100 percentages of missing entries
# The field ---lactose_100g-- contained 1017440 missing entries : 1017440/1017858 = 100 percentages of missing entries
# The field ---maltose_100g-- contained 1017849 missing entries : 1017849/1017858 = 100 percentages of missing entries
# The field ---maltodextrins_100g-- contained 1017844 missing entries : 1017844/1017858 = 100 percentages of missing entries
# The field --starch_100g-- contained 1017476 missing entries : 1017476/1017858 = 100 percentages of missing entries
# The field --polyols_100g-- contained 1017081 missing entries : 1017081/1017858 = 100 percentages of missing entries
# The field --fiber_100g-- contained 716130 missing entries : 716130/1017858 = 70 percentages of missing entries
# The field --proteins_100g-- contained 205246 missing entries : 205246/1017858 = 20 percentages of missing entries
# The field --casein_100g-- contained 1017820 missing entries : 1017820/1017858 = 100 percentages of missing entries
# The field --serum-proteins_100g-- contained 1017824 missing entries : 1017824/1017858 = 100 percentages of missing entries
# The field --nucleotides_100g-- contained 1017846 missing entries : 1017846/1017858 = 100 percentages of missing entries
# The field --salt_100g-- contained 225061 missing entries : 225061/1017858 = 22 percentages of missing entries
# The field --sodium_100g-- contained 225112 missing entries : 225112/1017858 = 22 percentages of missing entries
# The field --alcohol_100g-- contained 1005391 missing entries : 1005391/1017858 = 99 percentages of missing entries
# The field --vitamin-a_100g-- contained 878790 missing entries : 878790/1017858 = 86 percentages of missing entries
# The field --beta-carotene_100g-- contained 1017789 missing entries : 1017789/1017858 = 100 percentages of missing entries
# The field --vitamin-d_100g-- contained 1009447 missing entries : 1009447/1017858 = 99 percentages of missing entries
# The field --vitamin-e_100g-- contained 1015383 missing entries : 1015383/1017858 = 100 percentages of missing entries
# The field --vitamin-k_100g-- contained 1016835 missing entries : 1016835/1017858 = 100 percentages of missing entries
# The field --vitamin-c_100g-- contained 875233 missing entries : 875233/1017858 = 86 percentages of missing entries
# The field --vitamin-b1_100g-- contained 1005491 missing entries : 1005491/1017858 = 99 percentages of missing entries
# The field --vitamin-b2_100g-- contained 1006017 missing entries : 1006017/1017858 = 99 percentages of missing entries
# The field --vitamin-pp_100g-- contained 1005208 missing entries : 1005208/1017858 = 99 percentages of missing entries
# The field --vitamin-b6_100g-- contained 1009969 missing entries : 1009969/1017858 = 99 percentages of missing entries
# The field --vitamin-b9_100g-- contained 1011817 missing entries : 1011817/1017858 = 99 percentages of missing entries
# The field --folates_100g-- contained 1014776 missing entries : 1014776/1017858 = 100 percentages of missing entries
# The field --vitamin-b12_100g-- contained 1011543 missing entries : 1011543/1017858 = 99 percentages of missing entries
# The field --biotin_100g-- contained 1017296 missing entries : 1017296/1017858 = 100 percentages of missing entries
# The field --pantothenic-acid_100g-- contained 1014838 missing entries : 1014838/1017858 = 100 percentages of missing entries
# The field --silica_100g-- contained 1017758 missing entries : 1017758/1017858 = 100 percentages of missing entries
# The field --bicarbonate_100g-- contained 1017594 missing entries : 1017594/1017858 = 100 percentages of missing entries
# The field --potassium_100g-- contained 991704 missing entries : 991704/1017858 = 97 percentages of missing entries
# The field --chloride_100g-- contained 1017349 missing entries : 1017349/1017858 = 100 percentages of missing entries
# The field --calcium_100g-- contained 871772 missing entries : 871772/1017858 = 86 percentages of missing entries
# The field --phosphorus_100g-- contained 1011124 missing entries : 1011124/1017858 = 99 percentages of missing entries
# The field --iron_100g-- contained 875129 missing entries : 875129/1017858 = 86 percentages of missing entries
# The field --magnesium_100g-- contained 1010077 missing entries : 1010077/1017858 = 99 percentages of missing entries
# The field --zinc_100g-- contained 1013292 missing entries : 1013292/1017858 = 100 percentages of missing entries
# The field --copper_100g-- contained 1015563 missing entries : 1015563/1017858 = 100 percentages of missing entries
# The field --manganese_100g-- contained 1015994 missing entries : 1015994/1017858 = 100 percentages of missing entries
# The field --fluoride_100g-- contained 1017629 missing entries : 1017629/1017858 = 100 percentages of missing entries
# The field --selenium_100g-- contained 1016529 missing entries : 1016529/1017858 = 100 percentages of missing entries
# The field --chromium_100g-- contained 1017800 missing entries : 1017800/1017858 = 100 percentages of missing entries
# The field --molybdenum_100g-- contained 1017798 missing entries : 1017798/1017858 = 100 percentages of missing entries
# The field --iodine_100g-- contained 1017265 missing entries : 1017265/1017858 = 100 percentages of missing entries
# The field --caffeine_100g-- contained 1017611 missing entries : 1017611/1017858 = 100 percentages of missing entries
# The field --taurine_100g-- contained 1017764 missing entries : 1017764/1017858 = 100 percentages of missing entries
# The field --ph_100g-- contained 1017716 missing entries : 1017716/1017858 = 100 percentages of missing entries
# The field --fruits-vegetables-nuts_100g-- contained 1012102 missing entries : 1012102/1017858 = 99 percentages of missing entries
# The field --fruits-vegetables-nuts-dried_100g-- contained 1017575 missing entries : 1017575/1017858 = 100 percentages of missing entries
# The field --fruits-vegetables-nuts-estimate_100g-- contained 1007824 missing entries : 1007824/1017858 = 99 percentages of missing entries
# The field --collagen-meat-protein-ratio_100g-- contained 1017571 missing entries : 1017571/1017858 = 100 percentages of missing entries
# The field --cocoa_100g-- contained 1013359 missing entries : 1013359/1017858 = 100 percentages of missing entries
# The field --chlorophyl_100g-- contained 1017856 missing entries : 1017856/1017858 = 100 percentages of missing entries
# The field --carbon-footprint_100g-- contained 1017453 missing entries : 1017453/1017858 = 100 percentages of missing entries
# The field --carbon-footprint-from-meat-or-fish_100g-- contained 1008575 missing entries : 1008575/1017858 = 99 percentages of missing entries
# The field --nutrition-score-fr_100g-- contained 729485 missing entries : 729485/1017858 = 72 percentages of missing entries
# The field --nutrition-score-uk_100g-- contained 729485 missing entries : 729485/1017858 = 72 percentages of missing entries
# The field --glycemic-index_100g-- contained 1017855 missing entries : 1017855/1017858 = 100 percentages of missing entries
# The field --water-hardness_100g-- contained 1017858 missing entries : 1017858/1017858 = 100 percentages of missing entries
# The field --choline_100g-- contained 1017827 missing entries : 1017827/1017858 = 100 percentages of missing entries
# The field --phylloquinone_100g-- contained 1017854 missing entries : 1017854/1017858 = 100 percentages of missing entries
# The field --beta-glucan_100g-- contained 1017838 missing entries : 1017838/1017858 = 100 percentages of missing entries
# The field --inositol_100g-- contained 1017821 missing entries : 1017821/1017858 = 100 percentages of missing entries
# The field --carnitine_100g-- contained 1017843 missing entries : 1017843/1017858 = 100 percentages of missing entries
#                                   Nb NA % NA
# field
# code                                  0    0
# url                                   0    0
# creator                               3    0
# created_t                             0    0
# created_datetime                      1    0
# last_modified_t                       0    0
# last_modified_datetime                0    0
# product_name                      49872    5
# generic_name                     925571   91
# quantity                         699415   69
# packaging                        830876   82
# packaging_tags                   830883   82
# brands                           420303   41
# brands_tags                      420353   41
# categories                       642555   63
# categories_tags                  642559   63
# categories_en                    642559   63
# origins                          963001   95
# origins_tags                     963100   95
# manufacturing_places             931980   92
# manufacturing_places_tags        932015   92
# labels                           818467   80
# labels_tags                      818444   80
# labels_en                        818444   80
# emb_codes                        951918   94
# emb_codes_tags                   951947   94
# first_packaging_code_geo         975797   96
# cities                          1017858  100
# cities_tags                      972715   96
# purchase_places                  895031   88
# stores                           837691   82
# countries                          1742    0
# countries_tags                     1743    0
# countries_en                       1743    0
# ingredients_text                 569761   56
# allergens                        934726   92
# allergens_en                    1017858  100
# traces                           954395   94
# traces_tags                      936084   92
# traces_en                        936084   92
# serving_size                     739636   73
# serving_quantity                 739520   73
# no_nutriments                   1017858  100
# additives_n                      569883   56
# additives                       1017828  100
# additives_tags                   774039   76
# additives_en                     774039   76
# ingredients_from_palm_oil_n      569883   56
# ingredients_from_palm_oil       1017858  100
# ingredients_from_palm_oil_tags  1005782   99

# %% [markdown]
# ## Investigating new categories for diet type

# %% [markdown]
# First, we look at fields that can be used in order to create new diet type categorie

# %%
#categories field
print("The categories field contained %d not nan unique entries\n" % data[data.categories.notnull()].categories.unique().shape)
data[data["categories"].notnull()]["categories"].unique()
for categorie in data[data["categories"].notnull()]["categories"].unique()[:15]:
    print(categorie)
# Out:
# The categories field contained 79016 not nan unique entries
#
# Epicerie,Condiments,Sauces,Moutardes
# fr:Xsf
# Plats préparés, Légumes préparés, Carottes râpées, Carottes râpées assaisonnées
# Tartes, Tartes sucrées, Tartes à la noix de coco
# Aliments et boissons à base de végétaux, Aliments d'origine végétale, Aliments à base de fruits et de légumes, Desserts, Fruits et produits dérivés, Compotes, Compotes de poire
# Viandes, Volailles, Poulets, Aiguillettes de poulet
# Plats préparés, Légumes préparés, Entrées, Entrées froides, Macédoines de légumes préparées
# Produits laitiers, Produits fermentés, Produits laitiers fermentés, Fromages, Fromages de France, Abondance
# Viandes, Volailles, Poulets, Cuisses de poulet
# Aliments et boissons à base de végétaux, Aliments d'origine végétale, Céréales et pommes de terre, Pains, Pains spéciaux, Pains Bagel
# Aliments et boissons à base de végétaux, Aliments d'origine végétale, Céréales et pommes de terre, Pains, Baguettes
# Produits de la mer, Poissons, Saumons, Poissons fumés, Saumons fumés, Pavés de saumon, Pavés de saumon fumé
# Conserves, Viandes en conserve, Corned beef
# Produits de la mer, Poissons, Saumons, Pavés de saumon
# Plats préparés, Salades, Salades composées

# %%
#pnns_groups_1 field
print("The pnns_groups_1 field contained %d not nan unique entries" % data[data.pnns_groups_1.notnull()].pnns_groups_1.unique().shape)
for pnns in data[data["pnns_groups_1"].notnull()]["pnns_groups_1"].unique():
    print(pnns)
# Out:
# The pnns_groups_1 field contained 14 not nan unique entries
# unknown
# Fat and sauces
# Composite foods
# Sugary snacks
# Fruits and vegetables
# Fish Meat Eggs
# Milk and dairy products
# Cereals and potatoes
# sugary-snacks
# Beverages
# Salty snacks
# fruits-and-vegetables
# cereals-and-potatoes
# salty-snacks

# %%
#pnns_groups_2 field
print("The pnns_groups_2 field contained %d not nan unique entries" % data[data.pnns_groups_2.notnull()].pnns_groups_2.unique().shape)
for pnns in data[data["pnns_groups_2"].notnull()]["pnns_groups_2"].unique():
    print(pnns)
# Out:
# The pnns_groups_2 field contained 46 not nan unique entries
# unknown
# Dressings and sauces
# One-dish meals
# Biscuits and cakes
# Fruits
# Meat
# Cheese
# Bread
# Fish and seafood
# Dried fruits
# Legumes
# Vegetables
# Dairy desserts
# pastries
# Fruit juices
# Sweetened beverages
# Unsweetened beverages
# Pizza pies and quiche
# Sweets
# Alcoholic beverages
# Salty and fatty products
# Cereals
# Appetizers
# Fats
# Processed meat
# Nuts
# Chocolate products
# Milk and yogurt
# Ice cream
# Breakfast cereals
# vegetables
# Teas and herbal teas and coffees
# Sandwiches
# Soups
# Potatoes
# Artificially sweetened beverages
# Plant-based milk substitutes
# Offals
# fruits
# Eggs
# Waters and flavored waters
# Fruit nectars
# cereals
# Pizza pies and quiches
# legumes
# nuts

# %%
#labels_en
print("The labels_en field contained %d not nan unique entries" % data[data.labels_en.notnull()].labels_en.unique().shape)
for label in data[data["labels_en"].notnull()]['labels_en'].unique()[:50]:
    print(label)
# Out:
# The labels_en field contained 35106 not nan unique entries
# fr:delois-france
# Organic
# Organic,EU Organic,FR-BIO-01
# Organic,EU Organic,EU/non-EU Agriculture,FR-BIO-15
# Organic,EU Organic,fr:ab-agriculture-biologique
# Made in France
# Low or no fat,Low fat,Organic,High fibres
# fr:viande-francaise,Made in France
# Green Dot
# Contains GMOs
# Nutriscore,Nutriscore Grade A
# Made in Spain
# Organic,EU Organic,FR-BIO-10,fr:ab-agriculture-biologique
# Kosher,Contains GMOs
# No artificial flavors,Contains GMOs
# Gluten-free
# Incorrect data on label
# Not advised for specific people,PDO,Made in France,With sulfites,fr:Déconseillé aux femmes enceintes,fr:Origine France,fr:Triman
# Sustainable farming,UTZ Certified,UTZ Certified Cacao
# Do not freeze again
# Low or no sugar,Contains a source of phenylalanine,Excessive consumption can have laxative effects,Green Dot,No sugar,With sweeteners
# Vegetarian,No artificial colors,No flavors,No preservatives
# Organic,EU Organic,NL-BIO-01
# de:0000080176800
# Vegetarian,Vegan
# No preservatives,No thickening agent
# Gluten-free,Palm oil free
# Organic,EU Organic,FR-BIO-10
# No colorings
# Made in France,No preservatives
# Gluten-free,No lactose
# No colorings,No preservatives
# Organic,EU Organic,FR-BIO-01,fr:ab-agriculture-biologique
# No preservatives
# Green Dot,Made in France
# Vegetarian,Gluten-free,No GMOs,High proteins,Superior quality,fr:Triman
# Vegetarian,Gluten-free,No GMOs,High proteins
# PGI
# Organic,EU Organic,IT-BIO-009
# Organic,EU Organic,Gluten-free,FR-BIO-01,No added sugar,No lactose,Palm oil free
# Gluten-free,No preservatives
# Vegetarian,Gluten-free,Vegan,No lactose
# Vegetarian,Vegan,No added sugar,No lactose
# Vegetarian,Gluten-free,Vegan,No added sugar,No lactose
# Organic,EU Organic,FR-BIO-01,Made in France
# No additives,No colorings
# French meat,fr:Viande Bovine Française
# No artificial flavors,Green Dot,No artificial colors
# Pure butter
# Vegetarian,Green Dot,Pure butter

# %%
#ingredients_text
print("The ingredients_text field contained %d not nan unique entries \n" % data[data.ingredients_text.notnull()].ingredients_text.unique().shape)
for label in data[data["ingredients_text"].notnull()]['ingredients_text'].unique()[:50]:
    print(label + '\n')
# Out:
# The ingredients_text field contained 393971 not nan unique entries
#
# eau graines de téguments de moutarde vinaigre de vin rouge sel vin rouge sucre   moût de raisin (6.2%) oignons colorants extraits de carotte et extrait de paprika huile de tournesol son de moutarde sel (cette _moutarde_ uniquement disponible chez courte paille)
#
# antioxydant : érythorbate de sodium, colorant : caramel - origine UE), tomate 33,3%, MAYONNAISE 11,1% (huile de colza 78,9%, eau, jaunes d'OEUF 6%, vinaigre, MOUTARDE [eau, graines de MOUTARDE, sel, vinaigre, curcuma], sel, dextrose, stabilisateur : gomme de cellulose, conservateur : sorbate de potassium, colorant : ?-carotène, arôme)
#
# Lait entier, sucre, amidon de maïs, cacao, Agar agar.
#
# baguette Poite vin Pain baguette 50,6%: farine de BLÉ, eau, sel, levure, GLUTEN, farine de BLE maité, levure désactivée, acide ascorbique, Garniture FROMAGE mi-chèvre 46% (LAIT pasteurisé [95 0% LAIT de vache, 5 0% LAIT de chèvre], sel, FERMENTS LACTIQUES et daffinage, coagulant), tomate saladg 20,4%, huile d'olive I basilic 1%
#
# Paln suédois 42,6%: farine de BLÉ, eau, farine de SEIGLE, sucre, huile de colza non hydrogénée, sirop de sucre, gluten de BLÉ, sel, levure, levain en poudre (SEIGLE), poudre à lever: E503, fructose, agent de traitement de la farine: E300, enzymes. Garniture 57,4%: SAUMON Atlantique, sel origine Frane6,-Fdorvège, ÉëòS%EChlli), salade 29,6%, FROMAGE BLANO.Z,8% MG 14,8%, c)b'oulette
#
# Taboulé 76,2%, légumes 12%, huile de colza, sel , menthe, jus de citron, sucre, conservateur : E202, arôme
#
# Bananas, vegetable oil (coconut oil, corn oil and/or palm oil) sugar, natural banana flavor.
#
# Peanuts, wheat flour, sugar, rice flour, tapioca starch, salt, leavening (ammonium bicarbonate, baking soda), soy sauce (water, soybeans, wheat, salt), potato starch.
#
# FROMAGE BLANC 7.896 MG 73,304, crème de marron vanillée 26,71 % (sucre. pur60 do châtaignes 38%, naturel do vanil!o).
#
# pain aux 6 céréqles 61,7 % farine (farine de BLÉ, GLUTEN de BLE), eu, mélange 6 céréales-3 graines 17,6% (farine de BLE complet, crème d'ORGE, farine d'AVOlNE, farine de maïs, semoule de BLÉ dur, graines cie millet, graines de lin, graines de SÉSAME, farine de SEIGLE), sel, levure, garniture 38,3% , coppa 30,2% (échine de porc, sel, dextrose de maïs, fenouil, arome naturel, sucre, conservateur: nitrate de potassium et nitrite de sodium -origine UE), salade 30,2%, tomate 30,2%, basilic 5%, huile d'olive.
#
# Bâguette Bressan Pain baguette 46,2%,' farine de BLÉ, eau, sel, levure, GLUTEN, farine de BLE malté, levure désactivée, acide ascorbique, Garniture 53,8%: filet de poulet braisé 34,3% (filet de poulet 82%, eau, acidifiant : lactate de potassium et acétate de sodium, amidon modifié de manioc, sel, dextrose glucose, arômes, gélifiants E407ayaM$xydant : érythèfbate de sodium, colorant : grafnel • origine UE), tomateN25x8%, OEUF dur 22,70/ , 'salade 17,20/ O
#
# Organic hazelnuts, organic cashews, organic walnuts almonds, organic sunflower oil, sea salt.
#
# Organic polenta
#
# Rolled oats, grape concentrate, expeller pressed canola oil, sunflower seeds, almonds, walnuts oat bran, sesame seeds, cashews, natural vitamin e.
#
# Organic long grain white rice
#
# Org oats, org hemp granola (org oats, evaporated cane juice, org expeller-pressed canola oil, crispy rice [org brown rice flour, org evaporated cane juice, org molasses, sea salt], org flax seeds, org oat solids, hemp seeds), org raisins, org dates, org almonds, org hazelnuts, org coconut, org sunflower seeds, org pumpkin seeds, org flax seeds, org corn flakes (org corn meal, org grape and/or pear juice concentrate, sea salt), org quinoa amaranth flakes (org corn meal, org yellow corn flour, org evaporated cane juice, org flax, org buckwheat flour, org quinoa, org amaranth, sea salt, tocopherols [natural vitamin e]).
#
# Organic chocolate liquor, organic raw cane sugar, organic cocoa butter, organic unrefined whole cane sugar, organic ground vanilla beans.
#
# Organic expeller pressed, refined high oleic sunflower oil
#
# Organic adzuki beans
#
# Organic refined durum semolina wheat flour
#
# Roasted peanuts (peanuts, peanut or canola oil, salt), sesame sticks (unbleached wheat flour, sesame seeds, sunflower oil, sa;t, beet powder, turmeric), chili crackers (rice, corn starch, soy sauce[water, soybeans, wheat, salt], brown rice syrup, paprika, onion powder, garlic powder), tamari roasted almonds (almonds, tamari shoyu [water, wheat, soybeans, salt]), salt
#
# Organic golden flax seeds
#
# Organic dry roasted pumpkin seeds, tamari (soybeans, water and salt), garlic and cayenne.
#
# Organic rolled oats, honey, raisins, almonds, sunflower seeds, walnuts, wheat germ, unrefined expeller-pressed safflower oil, molasses, cinnamon
#
# Organic raw hazelnuts.
#
# Organic bananas, organic coconut oil, organic sugar
#
# Organic brown jasmine rice
#
# Organic oat groats
#
# Yogurt raisins, tamari roasted almonds, organic tamari roasted soy nuts, dark chocolate stars, cranberries, dark chocolate chips, peanut butter chips, milk chocolate raisins, pineapple, papaya, peanut butter peanuts & raisins, roasted peanuts.
#
# Chocolate stars (dehydrated cane juice, sweetened chocolate, cocoa butter, soy lecithin [an emulsifier], natural vanilla), roasted peanuts (peanuts, safflower, peanut, and/or canola oil, salt), dry roasted almonds (almonds, sea salt), dry roasted cashews (cashews, sea salt), dried cranberries (cranberries, evaporated cane juice, sunflower oil), dried cherries, walnuts, dried blueberries (blueberries, evaporated cane juice, sunflower oil).
#
# Organic rolled oats, organic evaporated cane juice, organic quinoa flakes, organic raisins, organic expeller pressed canola oil, organic mango, organic oat bran, organic coconut.
#
# Dry roasted almonds, hatch green chile seasoning (organic cheddar cheese powder [organic cheddar cheese {cultured pasteurized milk, salt, enzymes}, organic nonfat milk,organic whey, salt, sodium phosphate], salt, hatch green chile pepper, evaporated cane juice, onion, parsely, natural flavors,garlic, maltodextrin, spices, spices extractives, citric acid), expeller pressed canola oil.
#
# Peanut butter (dry roasted peanuts, palm oil, salt), honey, crispy brown rice (brown rice flour [rice flour, rice bran], honey, calcium carbonate), barley malt, soy lecithin (an emulsifier), sea salt, locust bean gum, carrageenan gum.
#
# Ancient sea salt with natural trace minerals
#
# Organic whole rolled oats, organic expeller pressed canola oil, organic raisins, organic coconut, organic corn meal, organic flax seed, organic freeze dried raspberries, organic freeze dried blueberries, organic vanilla, salt.
#
# Whole cashews, sunflower oil, salt, black pepper
#
# Cashews, curry seasoning (salt, maltodextrin, spices, torula yeast, onion, garlic, turmeric, extractives of spice and natural flavor), canola oil.
#
# Almonds, wasabi spice (salt, rice flour, evaporated cane juice, onion powder, spice extracts, horseradish powder, yeast extract, dried parsley, spice, garlic powder, citric acid), tamari shoyu sauce (water, soybeans, salt, wheat)
#
# Organic coconut
#
# Organic red quinoa
#
# Coconut bar (coconut, brown rice syrup), dark chocolate coating (unsweetened chocolate, dehydrated cane juice, cocoa butter, soy lecithin [as an emulsifier], natural vanilla).
#
# Organic semi-sweet chocolate chips (organic sugar, organic chocolate liquor, organic cocoa butter, soy lecithin, organic vanilla), organic pumpkin seeds, organic almonds, organic cranberries (sweetened with organic cane juice), organic raisins, organic coconut, organic sunflower seeds.
#
# Organic whole rolled oates, organic raisins, organic expeller pressed canola oil, organic flax seed, organic corn meal, organic almonds, organic coconut, organic cinnamon, salt.
#
# Organic rolled oats, organic evaporated cane juice, organic expeller pressed canola oil, organic raisins, organic apples, organic almonds, organic oat bran, organic blueberries, organic sunflower seeds.
#
# Raw cane demerara sugar.
#
# Organic rolled oats, flame raisins, organic coconut chips, organic maple syrup, sunflower oil, walnuts, roasted diced almonds, wheat germ, honey, crunchy almond butter (dry roasted almonds), hazelnuts, almonds, organic ground cinnamon, organic vanilla extract.
#
# Organic coconut.
#
# Organic black beans
#
# Bluebird grain organic grain emmer farro
#
# Organic hard red wheat berries.

# %% [markdown]
# ## Type of diet to create new diet category

# %% [markdown]
# Most popular diet according to https://www.medicalnewstoday.com/articles/5847.php

# %% [markdown]
# #### __The Atkins diet__
# https://www.medicalnewstoday.com/articles/7379.php#foods_to_eat_and_avoid
#
# When a person is on the Atkins Diet, their body's metabolism switches from burning glucose, or sugar, as fuel to burning its own stored body fat. This switching is called ketosis.
# * focuses on controlling the levels of insulin in the body through a low-carbohydrate diet.
#
# _Foods to eat/drink includes_:
# * meats, including beef, pork, and bacon
# * fatty fish and seafood
# * eggs
# * avocados
# * low-carb vegetables, such as kale, broccoli and asparagus
# * full-fat dairy products
# * nuts and seeds
# * healthy fats, such as extra-virgin olive oil, coconut oil, and avocado oil
# * water
# * coffee
# * green tea
#
# _Foods to avoid includes_:
# * sugar, such as soft drinks, cakes, and candy
# * grains including wheat, spelt, and rice
# * "diet" and "low-fat" foods, as they can be high in sugar
# * legumes, such as lentils, beans, and chickpeas
# * high-carb fruits (bananas, apples, grapes)
# * high-carb vegetables(carrots)

# %% [markdown]
# #### __The Zone diet__
# https://www.medicalnewstoday.com/articles/7382.php
# Keeping insulin levels within the therapeutic zone means staying in "The Zone." Zone diet foods need to be taken in the right proportions to help to control insulin production.
# Zone diet meal plans focus on eating:
# * low-density carbohydrates
# * dietary fat
# * protein
#
# People who follow the diet should balance carbohydrates, fats, and proteins in the following proportions:
# * 40 percent carbohydrate
# * 30 percent fat
# * 30 percent protein
# The idea is that by roughly balancing these three things in each meal, a person's health and weight will improve.
#
# In the Zone diet, calorie intake does not have to go down, but what the person is eating has to change.

# %% [markdown]
# #### __The Ketogenic diet__
# https://www.medicalnewstoday.com/articles/180858.php
#
# Ketosis is a normal metabolic process. When the body does not have enough glucose for energy, it burns stored fats instead; this results in a build-up of acids called ketones within the body.
#
# Some people encourage ketosis by following a diet called the ketogenic or low-carb diet. The aim of the diet is to try and burn unwanted fat by forcing the body to rely on fat for energy, rather than carbohydrates.
#
# Facts on ketosis:
# * Ketosis occurs when the body does not have sufficient access to its primary fuel source, glucose.
# * Ketosis describes a condition where fat stores are broken down to produce energy, which also produces ketones, a type of acid.
# * As ketone levels rise, the acidity of the blood also increases, leading to ketoacidosis, a serious condition that can prove fatal.
# * People with type 1 diabetes are more likely to develop ketoacidosis, for which emergency medical treatment is required to avoid or treat diabetic coma.
# * Some people follow a ketogenic (low-carb) diet to try to lose weight by forcing the body to burn fat stores.
#
# The diet itself can be regarded as a high-fat diet, with around
# * 75 percent of calories derived from fats
# * 20 percent of calories derived from proteins
# * 5 percent of calories derived carbohydrates

# %% [markdown]
# #### __The Vegetarian diet__
# https://www.medicalnewstoday.com/articles/8749.php#benefits
#
# A vegetarian does not eat meat or fish, but there are different types of vegetarian. Some consume eggs and dairy products, while the strictest kind, vegans, eat no animal produce at all, including honey. Some people call themselves vegetarians, but they consume fish.
#
# Here, we will focus on lacto-ovo-vegetarians, people who do not consume meat, fish and related products, but who do eat eggs, dairy products, and honey.

# %% [markdown]
# #### __The Vegan diet__
#
# https://www.medicalnewstoday.com/articles/149636.php
#
# A vegan diet is part of a lifestyle that excludes the consumption or use of any products made from animals. Vegans do not eat animal products, including honey, eggs, gelatin, or dairy
# * low in saturated fat
# * rich in nutrient
# * proteins, vitamins, and minerals must come from non-animal sources
